# %%
import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-mpnet-base-v2')

# %%
movies = pd.read_excel('data/movies_df_without_embeddings.xlsx')

# %%
movies
# Out:
#       movieId    budget original_language  popularity    revenue  runtime  \
# 0           1  30000000                en     102.775  394400000       81
# 1           2  65000000                en      15.210  262821940      104
# 2           3  25000000                en      12.835   71500000      101
# 3           4  16000000                en      14.973   81452156      127
# 4           5         0                en      17.414   76594107      106
# ...       ...       ...               ...         ...        ...      ...
# 9682   193581         0                ja      11.584          0      100
# 9683   193583         0                ja      16.119    6000000      106
# 9684   193585         0                en       3.280          0       96
# 9685   193587         0                ja      15.519          0       90
# 9686   193609         0                en       3.343          0       85
#
#       vote_average  vote_count  \
# 0            7.970       17264
# ...

# %%
embeddings = []
num_dimensions = 768
for index, row in tqdm(movies.iterrows()):
    overview = row["overview"]
    #print(overview)
    if isinstance(overview, str):
        embedding = list(model.encode(overview))
    else:    
        embedding = [0.0 for _ in range(num_dimensions)]
        
    embeddings.append(embedding)
movies["overview_embeddings"] = embeddings
# Out:
# 9687it [09:20, 17.30it/s]

# %%
movies = movies.set_index('movieId')

# %%
movies.head(3)
# Out:
#            budget original_language  popularity    revenue  runtime  \
# movieId
# 1        30000000                en     102.775  394400000       81
# 2        65000000                en      15.210  262821940      104
# 3        25000000                en      12.835   71500000      101
#
#          vote_average  vote_count  \
# movieId
# 1               7.970       17264
# 2               7.238        9887
# 3               6.494         350
#
#                                                   overview  \
# movieId
# 1        Led by Woody, Andy's toys live happily in his ...
# 2        When siblings Judy and Peter discover an encha...
# 3        A family wedding reignites the ancient feud be...
#
#                                                       tags  \
# movieId
# 1        ['martial arts', 'jealousy', 'friendship', 'bu...
# 2        ['giant insect', 'board game', 'jungle', 'disa...
# 3        ['fishing', 'halloween', 'sequel', 'old man', ...
#
# ...

# %%
#Save as excel file
movies.to_excel("data/movies_df.xlsx")
